# %%
import matplotlib.pyplot as plt
import numpy as np
import pickle

# %%
NODE_ID = 25

# %%
BASE_PATH = '/Users/ashfaq/Documents/alibaba_gnn_results'

# %%
RESULTS_FOLDER_PATH = f'{BASE_PATH}/workload_prediction_results_{NODE_ID}'

# %%
univariate_with_embedding_path_3 = f'{RESULTS_FOLDER_PATH}/univariate_with_embedding/results/informer_sl12_ll6_pl3_dm1024_nh8_el2_dl1_df2048_atprob_fc5_ebtimeF_dtTrue_mxTrue'

univariate_without_embedding_path_3 = f'{RESULTS_FOLDER_PATH}/univariate_with_embedding/results/informer_sl12_ll6_pl3_dm1024_nh8_el2_dl1_df2048_atprob_fc5_ebtimeF_dtTrue_mxTrue'

univariate_with_embedding_path_12 = f'{RESULTS_FOLDER_PATH}/univariate_with_embedding_long_range_pred/results/informer_sl48_ll24_pl12_dm1024_nh8_el2_dl1_df2048_atprob_fc5_ebtimeF_dtTrue_mxTrue'

univariate_without_embedding_path_12 = f'{RESULTS_FOLDER_PATH}/univariate_without_embedding_long_range_pred/results/informer_sl48_ll24_pl12_dm1024_nh8_el2_dl1_df2048_atprob_fc5_ebtimeF_dtTrue_mxTrue'

univariate_with_embedding_path_24 = f'{RESULTS_FOLDER_PATH}/univariate_with_embedding_long_range_pred_24/results/informer_sl96_ll48_pl24_dm1024_nh8_el2_dl1_df2048_atprob_fc5_ebtimeF_dtTrue_mxTrue'

univariate_without_embedding_path_24 = f'{RESULTS_FOLDER_PATH}/univariate_without_embedding_long_range_pred_24/results/informer_sl96_ll48_pl24_dm1024_nh8_el2_dl1_df2048_atprob_fc5_ebtimeF_dtTrue_mxTrue'

univariate_with_embedding_path_60 = f'{RESULTS_FOLDER_PATH}/univariate_with_embedding_long_range_pred_60/results/informer_sl240_ll120_pl60_dm1024_nh8_el2_dl1_df2048_atprob_fc5_ebtimeF_dtTrue_mxTrue'

univariate_without_embedding_path_60 = f'{RESULTS_FOLDER_PATH}/univariate_without_embedding_long_range_pred_60/results/informer_sl240_ll120_pl60_dm1024_nh8_el2_dl1_df2048_atprob_fc5_ebtimeF_dtTrue_mxTrue'

multivariate_with_embedding_path_3 = f'{RESULTS_FOLDER_PATH}/multivariate_with_embedding/results/informer_sl12_ll6_pl3_dm2048_nh8_el2_dl1_df2048_atprob_fc5_ebtimeF_dtTrue_mxTrue'

multivariate_without_embedding_path_3 = f'{RESULTS_FOLDER_PATH}/multivariate_without_embedding/results/informer_sl12_ll6_pl3_dm2048_nh8_el2_dl1_df2048_atprob_fc5_ebtimeF_dtTrue_mxTrue'

# %%
metrics_univariate_with_emb_3 = np.load(f'{univariate_with_embedding_path_3}/metrics.npy')
metrics_univariate_without_emb_3 = np.load(f'{univariate_without_embedding_path_3}/metrics.npy')

metrics_univariate_with_emb_12 = np.load(f'{univariate_with_embedding_path_12}/metrics.npy')
metrics_univariate_without_emb_12 = np.load(f'{univariate_without_embedding_path_12}/metrics.npy')

metrics_univariate_with_emb_24 = np.load(f'{univariate_with_embedding_path_24}/metrics.npy')
metrics_univariate_without_emb_24 = np.load(f'{univariate_without_embedding_path_24}/metrics.npy')

metrics_univariate_with_emb_60 = np.load(f'{univariate_with_embedding_path_60}/metrics.npy')
metrics_univariate_without_emb_60 = np.load(f'{univariate_without_embedding_path_60}/metrics.npy')

metrics_multivariate_with_emb = np.load(f'{multivariate_with_embedding_path_3}/metrics.npy')
metrics_multivariate_without_emb = np.load(f'{multivariate_without_embedding_path_3}/metrics.npy')

# %%
mae_values = [
    metrics_univariate_with_emb_3[0], metrics_univariate_without_emb_3[0],
    metrics_univariate_with_emb_12[0], metrics_univariate_without_emb_12[0],
    metrics_univariate_with_emb_24[0], metrics_univariate_without_emb_24[0],
    metrics_univariate_with_emb_60[0], metrics_univariate_without_emb_60[0],
    metrics_multivariate_with_emb[0], metrics_multivariate_without_emb[0]
]

mse_values = [
    metrics_univariate_with_emb_3[1], metrics_univariate_without_emb_3[1],
    metrics_univariate_with_emb_12[1], metrics_univariate_without_emb_12[1],
    metrics_univariate_with_emb_24[1], metrics_univariate_without_emb_24[1],
    metrics_univariate_with_emb_60[1], metrics_univariate_without_emb_60[1],
    metrics_multivariate_with_emb[1], metrics_multivariate_without_emb[1]
]

mape_values = [
    metrics_univariate_with_emb_3[3], metrics_univariate_without_emb_3[3],
    metrics_univariate_with_emb_12[3], metrics_univariate_without_emb_12[3],
    metrics_univariate_with_emb_24[3], metrics_univariate_without_emb_24[3],
    metrics_univariate_with_emb_60[3], metrics_univariate_without_emb_60[3],
    metrics_multivariate_with_emb[3], metrics_multivariate_without_emb[3]
]

# %%
labels = ['Uni_f_3', 'Uni_f_12', 'Uni_f_24', 'Uni_f_60', 'Multi_f_3']
x = np.arange(len(labels))  # the label locations
width = 0.35  # the width of the bars

fig, axes = plt.subplots(1, 3, figsize=(18, 6))

# MAE
axes[0].bar(x - width/2, mae_values[::2], width, label='With Temp Embedding')
axes[0].bar(x + width/2, mae_values[1::2], width, label='Without Temp Embedding')
axes[0].set_title('MAE')
axes[0].set_xticks(x)
axes[0].set_xticklabels(labels)
axes[0].legend()

# MSE
axes[1].bar(x - width/2, mse_values[::2], width, label='With Temp Embedding')
axes[1].bar(x + width/2, mse_values[1::2], width, label='Without Temp Embedding')
axes[1].set_title('MSE')
axes[1].set_xticks(x)
axes[1].set_xticklabels(labels)
axes[1].legend()

# MAPE
axes[2].bar(x - width/2, mape_values[::2], width, label='With Temp Embedding')
axes[2].bar(x + width/2, mape_values[1::2], width, label='Without Temp Embedding')
axes[2].set_title('MAPE')
axes[2].set_xticks(x)
axes[2].set_xticklabels(labels)
axes[2].legend()

plt.tight_layout()
plt.savefig(f'../plots/metrics/test_metrics_{NODE_ID}.png')
plt.show()

# %%
with open(f'{univariate_with_embedding_path_3}/losses.pickle', 'rb') as f:
    losses_univariate_with_emb_3 = pickle.load(f)
    
with open(f'{univariate_without_embedding_path_3}/losses.pickle', 'rb') as f:
    losses_univariate_without_emb_3 = pickle.load(f)
    
with open(f'{univariate_with_embedding_path_24}/losses.pickle', 'rb') as f:
    losses_univariate_with_emb_24 = pickle.load(f)
    
with open(f'{univariate_without_embedding_path_24}/losses.pickle', 'rb') as f:
    losses_univariate_without_emb_24 = pickle.load(f)
    
with open(f'{univariate_with_embedding_path_60}/losses.pickle', 'rb') as f:
    losses_univariate_with_emb_60 = pickle.load(f)
    
with open(f'{univariate_without_embedding_path_60}/losses.pickle', 'rb') as f:
    losses_univariate_without_emb_60 = pickle.load(f)
    
with open(f'{multivariate_with_embedding_path_3}/losses.pickle', 'rb') as f:
    losses_multivariate_with_emb = pickle.load(f)
    
with open(f'{multivariate_without_embedding_path_3}/losses.pickle', 'rb') as f:
    losses_multivariate_without_emb = pickle.load(f)

# %%
# Plotting the loss curves
fig, axes = plt.subplots(4, 2, figsize=(14, 16))

# Univariate 3 with/without embedding
axes[0, 0].plot(losses_univariate_with_emb_3['train'], label='Train')
axes[0, 0].plot(losses_univariate_with_emb_3['valid'], label='Valid')
axes[0, 0].set_title('Univariate 3 - With Temporal Embedding')
axes[0, 0].legend()

axes[0, 1].plot(losses_univariate_without_emb_3['train'], label='Train')
axes[0, 1].plot(losses_univariate_without_emb_3['valid'], label='Valid')
axes[0, 1].set_title('Univariate 3 - Without Temporal Embedding')
axes[0, 1].legend()

# Univariate 24 with/without embedding
axes[1, 0].plot(losses_univariate_with_emb_24['train'], label='Train')
axes[1, 0].plot(losses_univariate_with_emb_24['valid'], label='Valid')
axes[1, 0].set_title('Univariate 24 - With Temporal Embedding')
axes[1, 0].legend()

axes[1, 1].plot(losses_univariate_without_emb_24['train'], label='Train')
axes[1, 1].plot(losses_univariate_without_emb_24['valid'], label='Valid')
axes[1, 1].set_title('Univariate 24 - Without Temporal Embedding')
axes[1, 1].legend()

# Univariate 60 with/without embedding
axes[2, 0].plot(losses_univariate_with_emb_60['train'], label='Train')
axes[2, 0].plot(losses_univariate_with_emb_60['valid'], label='Valid')
axes[2, 0].set_title('Univariate 60 - With Temporal Embedding')
axes[2, 0].legend()

axes[2, 1].plot(losses_univariate_without_emb_60['train'], label='Train')
axes[2, 1].plot(losses_univariate_without_emb_60['valid'], label='Valid')
axes[2, 1].set_title('Univariate 60 - Without Temporal Embedding')
axes[2, 1].legend()

# Multivariate with/without embedding
axes[3, 0].plot(losses_multivariate_with_emb['train'], label='Train')
axes[3, 0].plot(losses_multivariate_with_emb['valid'], label='Valid')
axes[3, 0].set_title('Multivariate - With Temporal Embedding')
axes[3, 0].legend()

axes[3, 1].plot(losses_multivariate_without_emb['train'], label='Train')
axes[3, 1].plot(losses_multivariate_without_emb['valid'], label='Valid')
axes[3, 1].set_title('Multivariate - Without Temporal Embedding')
axes[3, 1].legend()

plt.tight_layout()
plt.savefig(f'../plots/metrics/loss_curves_{NODE_ID}.png')
plt.show()
