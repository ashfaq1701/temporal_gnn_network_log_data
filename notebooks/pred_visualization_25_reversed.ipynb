# %%
from pathlib import Path
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
TRAIN_NODE_ID=25
TEST_NODE_ID=25
IS_REVERSED=True

# %%
PREDS_BASE_PATH = '/Users/ashfaq/Documents/alibaba_gnn_results_7'

# %%
PLOTS_BASE_PATH = f'../plots/workload_preds/train_{TRAIN_NODE_ID}_test_{TEST_NODE_ID}'

path = Path(PLOTS_BASE_PATH)
path.mkdir(parents=True, exist_ok=True)

# %%
from src.utils import get_target_microservice_id

get_target_microservice_id()
# Out:
# np.int64(25)

# %%
from src.plot import plot_pred_and_true_workloads

plot_pred_and_true_workloads(
    f'{PREDS_BASE_PATH}/workload_prediction_results_{TRAIN_NODE_ID}/univariate_with_embedding/results/informer_sl12_ll6_pl3_dm1024_nh8_el2_dl1_df2048_atprob_fc5_ebtimeF_dtTrue_mxTrue/real_prediction.npy',
    'Univariate Workload Prediction Using Temporal Embedding (N_PAST=12 and N_FUTURE=3)',
    f'{PLOTS_BASE_PATH}/univariate_using_temporal_embedding.png',
    take_first=False,
    microservice_id=TEST_NODE_ID,
    is_reversed=IS_REVERSED
)

# %%
plot_pred_and_true_workloads(
    f'{PREDS_BASE_PATH}/workload_prediction_results_{TRAIN_NODE_ID}/univariate_without_embedding/results/informer_sl12_ll6_pl3_dm1024_nh8_el2_dl1_df2048_atprob_fc5_ebtimeF_dtTrue_mxTrue/real_prediction.npy',
    'Univariate Workload Prediction Without Using Temporal Embedding (N_PAST=12 and N_FUTURE=3)',
    f'{PLOTS_BASE_PATH}/univariate_without_using_temporal_embedding.png',
    take_first=False,
    microservice_id=TEST_NODE_ID,
    is_reversed=IS_REVERSED
)

# %%
plot_pred_and_true_workloads(
    f'{PREDS_BASE_PATH}/workload_prediction_results_{TRAIN_NODE_ID}/univariate_with_embedding_long_range_pred/results/informer_sl48_ll24_pl12_dm1024_nh8_el2_dl1_df2048_atprob_fc5_ebtimeF_dtTrue_mxTrue/real_prediction.npy',
    'Univariate Workload Prediction Using Temporal Embedding (N_PAST=48 and N_FUTURE=12)',
    f'{PLOTS_BASE_PATH}/univariate_long_term_using_temporal_embedding.png',
    take_first=False,
    microservice_id=TEST_NODE_ID,
    is_reversed=IS_REVERSED
)

# %%
plot_pred_and_true_workloads(
    f'{PREDS_BASE_PATH}/workload_prediction_results_{TRAIN_NODE_ID}/univariate_without_embedding_long_range_pred/results/informer_sl48_ll24_pl12_dm1024_nh8_el2_dl1_df2048_atprob_fc5_ebtimeF_dtTrue_mxTrue/real_prediction.npy',
    'Univariate Workload Prediction Without Using Temporal Embedding (N_PAST=48 and N_FUTURE=12)',
    f'{PLOTS_BASE_PATH}/univariate_long_term_without_using_temporal_embedding.png',
    take_first=False,
    microservice_id=TEST_NODE_ID,
    is_reversed=IS_REVERSED
)

# %%
plot_pred_and_true_workloads(
    f'{PREDS_BASE_PATH}/workload_prediction_results_{TRAIN_NODE_ID}/univariate_with_embedding_long_range_pred_24/results/informer_sl96_ll48_pl24_dm1024_nh8_el2_dl1_df2048_atprob_fc5_ebtimeF_dtTrue_mxTrue/real_prediction.npy',
    'Univariate Workload Prediction Using Temporal Embedding (N_PAST=96 and N_FUTURE=24)',
    f'{PLOTS_BASE_PATH}/univariate_long_term_using_temporal_embedding_24_minutes.png',
    take_first=False,
    microservice_id=TEST_NODE_ID,
    is_reversed=IS_REVERSED
)

# %%
plot_pred_and_true_workloads(
    f'{PREDS_BASE_PATH}/workload_prediction_results_{TRAIN_NODE_ID}/univariate_without_embedding_long_range_pred_24/results/informer_sl96_ll48_pl24_dm1024_nh8_el2_dl1_df2048_atprob_fc5_ebtimeF_dtTrue_mxTrue/real_prediction.npy',
    'Univariate Workload Prediction Without Using Temporal Embedding (N_PAST=96 and N_FUTURE=24)',
    f'{PLOTS_BASE_PATH}/univariate_long_term_without_using_temporal_embedding_24_minutes.png',
    take_first=False,
    microservice_id=TEST_NODE_ID,
    is_reversed=IS_REVERSED
)

# %%
plot_pred_and_true_workloads(
    f'{PREDS_BASE_PATH}/workload_prediction_results_{TRAIN_NODE_ID}/univariate_with_embedding_long_range_pred_60/results/informer_sl240_ll120_pl60_dm1024_nh8_el2_dl1_df2048_atprob_fc5_ebtimeF_dtTrue_mxTrue/real_prediction.npy',
    'Univariate Workload Prediction Using Temporal Embedding (N_PAST=240 and N_FUTURE=60)',
    f'{PLOTS_BASE_PATH}/univariate_long_term_using_temporal_embedding_60_minutes.png',
    take_first=False,
    microservice_id=TEST_NODE_ID,
    is_reversed=IS_REVERSED
)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 plot_pred_and_true_workloads(
#       2     f'{PREDS_BASE_PATH}/workload_prediction_results_{TRAIN_NODE_ID}/univariate_with_embedding_long_range_pred_60/results/informer_sl240_ll120_pl60_dm1024_nh8_el2_dl1_df2048_atprob_fc5_ebtimeF_dtTrue_mxTrue/real_prediction.npy',
#       3     'Univariate Workload Prediction Using Temporal Embedding (N_PAST=240 and N_FUTURE=60)',
#       4     f'{PLOTS_BASE_PATH}/univariate_long_term_using_temporal_embedding_60_minutes.png',
#       5     take_first=False,
#       6     microservice_id=TEST_NODE_ID,
#       7     is_reversed=IS_REVERSED
#       8 )
#
# File ~/PycharmProjects/temporal_gnn_network_log_data/src/plot/__init__.py:72, in plot_pred_and_true_workloads(filepath, title, save_filepath, take_first, microservice_id, is_reversed)
#      69 def plot_pred_and_true_workloads(
#      70         filepath, title, save_filepath, take_first=True, microservice_id=None, is_reversed=False
#      71 ):
# ---> 72     pred_workloads, true_workloads = get_pred_and_true_workloads(filepath, take_first, microservice_id, is_reversed)
#      74     train_days = int(os.getenv('WORKLOAD_PREDICTION_TRAINING_DAYS'))
#      75     valid_days = int(os.getenv('WORKLOAD_PREDICTION_VALIDATION_DAYS'))
#
# File ~/PycharmProjects/temporal_gnn_network_log_data/src/plot/__init__.py:42, in get_pred_and_true_workloads(filepath, take_first, microservice_id, is_reversed)
#      39 else:
#      40     target_microservice_id = get_target_microservice_id()
# ---> 42 preds = np.load(filepath)
#      43 pred_len = preds.shape[0] + preds.shape[1] - 1
#      44 selected_test_workloads = test_workloads[-pred_len:]
#
# File ~/.local/share/virtualenvs/temporal_gnn_network_log_data-EVKJPPHF/lib/python3.10/site-packages/numpy/lib/_npyio_impl.py:455, in load(file, mmap_mode, allow_pickle, fix_imports, encoding, max_header_size)
#     453     own_fid = False
#     454 else:
# --> 455     fid = stack.enter_context(open(os.fspath(file), "rb"))
#     456     own_fid = True
#     458 # Code to distinguish from NumPy binary files and pickles.
#
# FileNotFoundError: [Errno 2] No such file or directory: '/Users/ashfaq/Documents/alibaba_gnn_results_7/workload_prediction_results_25/univariate_with_embedding_long_range_pred_60/results/informer_sl240_ll120_pl60_dm1024_nh8_el2_dl1_df2048_atprob_fc5_ebtimeF_dtTrue_mxTrue/real_prediction.npy'

# %%
plot_pred_and_true_workloads(
    f'{PREDS_BASE_PATH}/workload_prediction_results_{TRAIN_NODE_ID}/univariate_without_embedding_long_range_pred_60/results/informer_sl240_ll120_pl60_dm1024_nh8_el2_dl1_df2048_atprob_fc5_ebtimeF_dtTrue_mxTrue/real_prediction.npy',
    'Univariate Workload Prediction Without Using Temporal Embedding (N_PAST=240 and N_FUTURE=60)',
    f'{PLOTS_BASE_PATH}/univariate_long_term_without_using_temporal_embedding_60_minutes.png',
    take_first=False,
    microservice_id=TEST_NODE_ID,
    is_reversed=IS_REVERSED
)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 plot_pred_and_true_workloads(
#       2     f'{PREDS_BASE_PATH}/workload_prediction_results_{TRAIN_NODE_ID}/univariate_without_embedding_long_range_pred_60/results/informer_sl240_ll120_pl60_dm1024_nh8_el2_dl1_df2048_atprob_fc5_ebtimeF_dtTrue_mxTrue/real_prediction.npy',
#       3     'Univariate Workload Prediction Without Using Temporal Embedding (N_PAST=240 and N_FUTURE=60)',
#       4     f'{PLOTS_BASE_PATH}/univariate_long_term_without_using_temporal_embedding_60_minutes.png',
#       5     take_first=False,
#       6     microservice_id=TEST_NODE_ID,
#       7     is_reversed=IS_REVERSED
#       8 )
#
# File ~/PycharmProjects/temporal_gnn_network_log_data/src/plot/__init__.py:72, in plot_pred_and_true_workloads(filepath, title, save_filepath, take_first, microservice_id, is_reversed)
#      69 def plot_pred_and_true_workloads(
#      70         filepath, title, save_filepath, take_first=True, microservice_id=None, is_reversed=False
#      71 ):
# ---> 72     pred_workloads, true_workloads = get_pred_and_true_workloads(filepath, take_first, microservice_id, is_reversed)
#      74     train_days = int(os.getenv('WORKLOAD_PREDICTION_TRAINING_DAYS'))
#      75     valid_days = int(os.getenv('WORKLOAD_PREDICTION_VALIDATION_DAYS'))
#
# File ~/PycharmProjects/temporal_gnn_network_log_data/src/plot/__init__.py:42, in get_pred_and_true_workloads(filepath, take_first, microservice_id, is_reversed)
#      39 else:
#      40     target_microservice_id = get_target_microservice_id()
# ---> 42 preds = np.load(filepath)
#      43 pred_len = preds.shape[0] + preds.shape[1] - 1
#      44 selected_test_workloads = test_workloads[-pred_len:]
#
# File ~/.local/share/virtualenvs/temporal_gnn_network_log_data-EVKJPPHF/lib/python3.10/site-packages/numpy/lib/_npyio_impl.py:455, in load(file, mmap_mode, allow_pickle, fix_imports, encoding, max_header_size)
#     453     own_fid = False
#     454 else:
# --> 455     fid = stack.enter_context(open(os.fspath(file), "rb"))
#     456     own_fid = True
#     458 # Code to distinguish from NumPy binary files and pickles.
#
# FileNotFoundError: [Errno 2] No such file or directory: '/Users/ashfaq/Documents/alibaba_gnn_results_7/workload_prediction_results_25/univariate_without_embedding_long_range_pred_60/results/informer_sl240_ll120_pl60_dm1024_nh8_el2_dl1_df2048_atprob_fc5_ebtimeF_dtTrue_mxTrue/real_prediction.npy'

# %%
plot_pred_and_true_workloads(
    f'{PREDS_BASE_PATH}/workload_prediction_results_{TRAIN_NODE_ID}/multivariate_with_embedding/results/informer_sl12_ll6_pl3_dm2048_nh8_el2_dl1_df2048_atprob_fc5_ebtimeF_dtTrue_mxTrue/real_prediction.npy',
    'Multivariate Workload Prediction Using Temporal Embedding (N_PAST=12 and N_FUTURE=3)',
    f'{PLOTS_BASE_PATH}/multivariate_using_temporal_embedding.png',
    take_first=False,
    microservice_id=TEST_NODE_ID,
    is_reversed=IS_REVERSED
)

# %%
plot_pred_and_true_workloads(
    f'{PREDS_BASE_PATH}/workload_prediction_results_{TRAIN_NODE_ID}/multivariate_without_embedding/results/informer_sl12_ll6_pl3_dm2048_nh8_el2_dl1_df2048_atprob_fc5_ebtimeF_dtTrue_mxTrue/real_prediction.npy',
    'Multivariate Workload Prediction Without Using Temporal Embedding (N_PAST=12 and N_FUTURE=3)',
    f'{PLOTS_BASE_PATH}/multivariate_without_using_temporal_embedding.png',
    take_first=False,
    microservice_id=TEST_NODE_ID,
    is_reversed=IS_REVERSED
)

# %%
from src.plot import plot_full_workloads

plot_full_workloads(
    f'{PREDS_BASE_PATH}/workload_prediction_results_{TRAIN_NODE_ID}/univariate_with_embedding_long_range_pred/results/informer_sl48_ll24_pl12_dm1024_nh8_el2_dl1_df2048_atprob_fc5_ebtimeF_dtTrue_mxTrue/real_prediction.npy',
    'Univariate Workload Prediction Using Temporal Embedding (N_PAST=48 and N_FUTURE=12)',
    f'{PLOTS_BASE_PATH}/univariate_long_term_using_temporal_embedding_FULL.png',
    take_first=False,
    microservice_id=TEST_NODE_ID,
    is_reversed=IS_REVERSED
)

# %%
plot_full_workloads(
    f'{PREDS_BASE_PATH}/workload_prediction_results_{TRAIN_NODE_ID}/univariate_with_embedding_long_range_pred_60/results/informer_sl240_ll120_pl60_dm1024_nh8_el2_dl1_df2048_atprob_fc5_ebtimeF_dtTrue_mxTrue/real_prediction.npy',
    'Univariate Workload Prediction Using Temporal Embedding (N_PAST=240 and N_FUTURE=60)',
    f'{PLOTS_BASE_PATH}/univariate_long_term_using_temporal_embedding_60_minutes_FULL.png',
    take_first=False,
    microservice_id=TEST_NODE_ID,
    is_reversed=IS_REVERSED
)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 plot_full_workloads(
#       2     f'{PREDS_BASE_PATH}/workload_prediction_results_{TRAIN_NODE_ID}/univariate_with_embedding_long_range_pred_60/results/informer_sl240_ll120_pl60_dm1024_nh8_el2_dl1_df2048_atprob_fc5_ebtimeF_dtTrue_mxTrue/real_prediction.npy',
#       3     'Univariate Workload Prediction Using Temporal Embedding (N_PAST=240 and N_FUTURE=60)',
#       4     f'{PLOTS_BASE_PATH}/univariate_long_term_using_temporal_embedding_60_minutes_FULL.png',
#       5     take_first=False,
#       6     microservice_id=TEST_NODE_ID,
#       7     is_reversed=IS_REVERSED
#       8 )
#
# File ~/PycharmProjects/temporal_gnn_network_log_data/src/plot/__init__.py:113, in plot_full_workloads(filepath, title, save_filepath, take_first, microservice_id, is_reversed, test_microservice)
#     110 else:
#     111     test_microservice_id = microservice_id
# --> 113 pred_workloads, true_workloads = get_pred_and_true_workloads(filepath, take_first, microservice_id, is_reversed)
#     114 train_workloads = get_train_workloads(microservice_id, is_reversed)
#     115 valid_workloads = get_valid_workloads(microservice_id, is_reversed)
#
# File ~/PycharmProjects/temporal_gnn_network_log_data/src/plot/__init__.py:42, in get_pred_and_true_workloads(filepath, take_first, microservice_id, is_reversed)
#      39 else:
#      40     target_microservice_id = get_target_microservice_id()
# ---> 42 preds = np.load(filepath)
#      43 pred_len = preds.shape[0] + preds.shape[1] - 1
#      44 selected_test_workloads = test_workloads[-pred_len:]
#
# File ~/.local/share/virtualenvs/temporal_gnn_network_log_data-EVKJPPHF/lib/python3.10/site-packages/numpy/lib/_npyio_impl.py:455, in load(file, mmap_mode, allow_pickle, fix_imports, encoding, max_header_size)
#     453     own_fid = False
#     454 else:
# --> 455     fid = stack.enter_context(open(os.fspath(file), "rb"))
#     456     own_fid = True
#     458 # Code to distinguish from NumPy binary files and pickles.
#
# FileNotFoundError: [Errno 2] No such file or directory: '/Users/ashfaq/Documents/alibaba_gnn_results_7/workload_prediction_results_25/univariate_with_embedding_long_range_pred_60/results/informer_sl240_ll120_pl60_dm1024_nh8_el2_dl1_df2048_atprob_fc5_ebtimeF_dtTrue_mxTrue/real_prediction.npy'
